# %%
import keyring
import getpass

# %%
keyring.set_password('spotify', 'cid', getpass.getpass())
# Out:
# ········

# %%
keyring.set_password('spotify', 'secret', getpass.getpass())
# Out:
# ········
