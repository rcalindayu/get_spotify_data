# %%
import numpy as np
import pandas as pd

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import keyring

# %% [markdown]
# ## Setup Spotipy credentials and query wrapper

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=keyring.get_password('spotify', 'cid'),
                                                      client_secret=keyring.get_password('spotify', 'secret') )
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ## Set keyword

# %%
KEYWORD = 'OPM'

# %% [markdown]
# ## View structure of a search query

# %%
results = sp.search(q=KEYWORD, type='playlist' , market='PH')

# %%
results

# %%
results['playlists'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results['playlists']['items'][0].keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %% [markdown]
# ## Get top 200 playlists for keyword

# %%
playlist_ids = []
playlist_names = []
playlist_numtracks = []
for n in np.arange(4):
    offset= 50*n
    results = sp.search(q=KEYWORD, type='playlist' , market='PH', offset = offset, limit=50)
    playlist_ids.extend([p['href'].split('/')[5] for p in results['playlists']['items']])
    playlist_names.extend([p['name'] for p in results['playlists']['items']])
    playlist_numtracks.extend([p['tracks']['total'] for p in results['playlists']['items']])

# %%
playlist_names
# Out:
# ['OPM Favorites',
#  'OPM Says Chillax',
#  "OPM Bands 90's - 00's",
#  'OPM Chill Songs 2020 ☕',
#  "OPM: Hits of the '00s",
#  "OPM: Hits of the '90s",
#  "OPM Lovesongs 80's 90's 20's",
#  "OPM: Hits of the '80s",
#  'OPM Classics',
#  'OPM Rising',
#  'OPM 2020 Playlist',
#  'OPM 2000s (Batang 90s)',
#  '',
#  'OPM Bands Greatest Hits',
#  'OPM HUGOT SONG 2020',
#  'OPM Acoustic Hits 2020 💛',
#  'OPM Workday Marathon',
#  'OPM Hits 2019 -2020',
#  'OPM Love songs 80s and 90s Ballads',
#  'OPM Love Songs & Covers',
#  "OPM TAGALOG LOVE SONGS 80's and 90's",
#  'OPM Sad Songs☹️',
#  'OPM Songs 2020 - OPM Love Songs Tagalog Playlist 2020 (New Filipino Song)',
#  "OPM Rock & Alternative 90's - 2010's",
#  'OPM Songs for Sleeping 😴',
#  'OPM Inuman Sessions',
#  'OPM Alternative Rock Hits',
#  "OPM 70's 80's Tagalog",
#  'Acoustically OPM',
#  'OPM Rock Songs',
#  'Top Hits Philippines',
#  'Acoustic OPM',
#  'Tatak Pinoy',
#  'Men of OPM',
#  'OPM Hits 2020 to 2021',
#  'Top OPM Artists of 2018',
#  'Women of OPM',
#  'Christmas OPM',
#  'Top OPM Artists of 2019',
#  'Broken Hearted OPM Songs 2020 💔',
#  'Rap Songs OPM 2020',
#  'Filipino Songs (OPM)',
#  'Chill OPM Songs',
#  'Chocolate Factory & OPM reggae',
#  'Pinoy Band Opm hits',
#  'Pinoy Classic Rock',
#  "Tunog Kalye / Pinoy Rock OPM Bands 90's",
#  'Best of Manila Sound',
#  'TAGALOG SONGS (OPM)',
#  'TUNOG KALYE (90"S OPM BANDS)',
#  "90's OPM bands",
#  "Love Songs OPM 00's",
#  '90s OPM Pinoy Love Songs',
#  '2000s OPM Nostalgia',
#  'This Is Eraserheads',
#  'Bago Sa Rap',
#  'Pampatulog / Acoustic OPM',
#  'Pinoy Reggae',
#  'TRENDING OPM 2020 ',
#  'Pinoy Covers',
#  'OPM Rap Music',
#  'Freestyle — OPM Medley and Side A',
#  'Jukebox OPM Hits',
#  'Wish 107.5 OPM',
#  'Broken hearted OPM Tagalog',
#  'Pinoy Rakrakan!',
#  'OPM Band Hits',
#  'Pinoy Love Ballads',
#  'Regae OPM',
#  "Tagalog' OPM Hits.....",
#  "BATANG 90's OPM Greatest Hits",
#  'Trending OPM Hits 2020',
#  'OPM MASHUP 2020 💕',
#  'New OPM Love Songs 2020 - Tagalog Music Playlist',
#  'Roadtrip Hits OPM Philippines',
#  'Disney Hits Philippines',
#  'O kay sarap sa ilalim ng kalawakan Kapag kapiling kang tumitig sa kawalan Saksi ang buwan at bituin',
#  'Filipino Love Songs ❣️ 🇵🇭  | OPM',
#  'Pinoy Rap 2020 👑',
#  'Best OPM Hits 2020 - OPM Love Songs Tagalog Playlist',
#  'Break-Up Playlist (OPM)',
#  'Bass Boosted OPM',
#  'Jaya OPM',
#  'Tagalog Opm lovesongs',
#  'Old School OPM Hits',
#  'OPM Acoustic Covers ❤️',
#  'Morning OPM',
#  'Saxophone 🎷 OPM',
#  'Pinoy acoustics and Senti OPM',
#  'Mood: Sad OPM',
#  'OPM: Pasko Na Naman',
#  'New Music Friday Philippines',
#  'BEST OF OPM RAP SONGS ',
#  'OPM LOVE SONGS',
#  "Rainy Night's OPM Jam",
#  'Heart Breaking Songs💔OPM🖤',
#  'Classic OPM Bands',
#  'OPM love song 2020',
#  'Indie OPM Feels',
#  'OPM Birit Songs',
#  'Latest OPM Songs',
#  'OPM/Tagalog Christmas Songs',
#  'OPM Old Tagalog Love songs 💕',
#  'Sad Songs Philippines 2020 😢',
#  'Pinoy Love Songs 2020 ❤',
#  "2000's OPM Band Hits",
#  'OPM acoustic love songs',
#  'Mashup opm 2020',
#  'Trending Hits Philippines 2020',
#  'Old Opm songs tagalog',
#  'Bagong OPM 2020',
#  'Religious Songs-OPM',
#  'OPM Bands 2004-2010',
#  "Tagalog OPM Best 90's/2000's hits",
#  'Senti - OPM',
#  'SENTI OPM HITS',
#  'Locals (OPM) 🇵🇭',
#  'Filipino OPM songs',
#  'Opm 2020 lovesong',
#  'Wish107.5 OPM mix ',
#  "Nina, MYMP, Freestyle & OPM's",
#  'Mellow OPM',
#  'This Is Sponge Cola',
#  'Opm acoustic covers',
#  'OPM Jukebox Hits📀📀📀',
#  'alternative rock #opm🇵🇭🇵🇭',
#  'NEW OPM Pinoy Covers 🌺 2019-2020',
#  'OPM Tiktok Hits 2020! 💃',
#  'Heartbreak Songs OPM 🇵🇭',
#  'OPM Top Hits 2020',
#  'Philippine OPM/Senti 2020',
#  'OPM 2000s & Late 90s',
#  'Classic OPM Rock',
#  "Tunog Kalye (OPM 90's Bands)",
#  '1990s (OPM)',
#  'NEW OPM 2019-2020',
#  'NEW OPM RAP 2020',
#  "Opm rock 2000's",
#  'OPM English Songs',
#  'OPM 90s - Chill',
#  'OPM English Love Songs 2020 💓',
#  'OPM Christmas songs',
#  'OPM 🇵🇭 mood',
#  'april boy songs and opm ',
#  'OPM sa Tag-Ulan 2020☔',
#  'Sunday OPM classics',
#  "2000's opm love songs",
#  'OPM CLASSIC (‘70s & ‘80s hits)',
#  "opm 80's to 90's",
#  'Reggae Pilipinas',
#  'Reggae Pilipinas',
#  'Cinderella OPM',
#  'OPM Sad Songs 2020 😢',
#  "OPM Hits 90's & 2000's",
#  "80's OPM Love Songs",
#  'OPM HIPHOP 2020',
#  'Pinoy OPM',
#  'Pinoy Alt Rock',
#  'OPM CHRISTMAS',
#  'Best OPM Band Collection',
#  '2005-2006 OPM Songs',
#  'OPM Piano Covers',
#  'RNB OPM LOVE SONGS',
#  'Classic OPM love songs',
#  'OPM Fever ',
#  'Top Opm 2020',
#  'Hugot Songs / OPM',
#  'OPM Chill',
#  'OPM Band Hits 2020 🎸',
#  'OPM Acoustic/Mellow Rock',
#  'Best OPM of all time',
#  'Tagalog opm bands 2020',
#  "OPM TAGALOG HITS 80'90",
#  'OPM Pampatulog Love Songs',
#  'OPM Instrumental Hits',
#  "OPM 80s-90's Jukebox",
#  'opm ktv',
#  'Tagalog Rap/OPM 2020!',
#  'OPM Alternative 90s',
#  'OPM alternative/rock 90s - 2020',
#  "90's opm love songs ❤",
#  'OPM Acoustic/Soul/Love Songs',
#  'Pinoy Rnb 2020 💜',
#  'Classic OPM Rap and OPM Hip-Hop',
#  'OPM Sunday Jukebox',
#  'OPM Oldies - Jukebox Hits',
#  'OPM 2004 to 2007',
#  'Female BIRIT songs (intl & opm)',
#  'Lasing na broken - OPM',
#  'Pabagalin muna natin ang ikot ng mundo Pahintuin mga kamay ng oras sa relo',
#  'Filipino Love Songs OPM',
#  'OPM | Higa, Tulala, Iyak',
#  'Tagalog Senti Songs 2020 💔',
#  'OPM love radio 90.7',
#  "80's OPM ballads",
#  'Year 2000 OPM Bands',
#  'OPM alternative rocks',
#  'COVER,OPM & SENTI SONGS',
#  'OPM Tagalog Songs',
#  'OPM Best Pinoy Pampatulog Songs']

# %% [markdown]
# ## View structure of a playlist query

# %%
playlist = sp.playlist('37i9dQZF1DX4olOMiqFeqU')

# %%
playlist

# %%
playlist.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %% [markdown]
# ## Get Playlist Data

# %%
playlist_lookup = []
for n,p_id in enumerate(playlist_ids):
    playlist = sp.playlist(p_id)
    try:
        relevant_playlist_data = { key: playlist[key] for key in ['followers','owner']}
        relevant_playlist_data['playlist_id'] = p_id
        relevant_playlist_data['playlist_names'] = playlist_names[n]
        relevant_playlist_data['playlist_total_tracks'] = playlist_numtracks[n]
        relevant_playlist_data['owner_id'] = playlist['owner']['id']
        relevant_playlist_data['owner_name'] = playlist['owner']['display_name']
        relevant_playlist_data['total_followers'] = playlist['followers']['total']
        relevant_playlist_data.pop('owner', None)
        relevant_playlist_data.pop('followers', None)
        playlist_lookup.append(relevant_playlist_data)
    except:
        continue

# %%
playlist_df = pd.DataFrame(playlist_lookup)
playlist_df =playlist_df.sort_values('total_followers',ascending=False)
playlist_df
# Out:
#                 playlist_id                playlist_names  \
# 30   37i9dQZF1DXcZQSjptOQtk          Top Hits Philippines
# 0    37i9dQZF1DX4olOMiqFeqU                 OPM Favorites
# 32   37i9dQZF1DX0iFfuXuP4Pm                   Tatak Pinoy
# 1    37i9dQZF1DX7Jerj8LqApV              OPM Says Chillax
# 91   37i9dQZF1DWVjrTQlvqTHF  New Music Friday Philippines
# ..                      ...                           ...
# 103  58zdc3mv6rEnuKYIb0fJTO  Sad Songs Philippines 2020 😢
# 171  5byY4odoEhAJ3mCN4mveTp        Tagalog opm bands 2020
# 123  5BYDziaKqhF2FvJR1h97MB           Opm acoustic covers
# 141  14vB1SjYBR33KunKaXco0E           OPM Christmas songs
# 107  2CUiFyr5jCdLEe7pQLzgoT               Mashup opm 2020
#
#      playlist_total_tracks                      owner_id  \
# 30                      52                       spotify
# 0                       50                       spotify
# 32                      60                       spotify
# 1                       40                       spotify
# 91                     106                       spotify
# ..                     ...                           ...
# 103                     34     jyhra99st5nhex8kfo4um2dh7
# 171                     42  31uybtfdnnuu33ugdqrddpsmrd24
# 123                     51                   12177596513
# 141                     62     0i1ck3bbu7s2w6r0m7mz8xl4x
# 107                     29  315xkyaww3o5j247bdtt4iaktlb4
#
#                     owner_name  total_followers
# 30                     Spotify          3863056
# 0                      Spotify          1983721
# 32                     Spotify          1286428
# 1                      Spotify          1160522
# 91                     Spotify           635808
# ..                         ...              ...
# 103                    buntala              180
# 171                  Eris Cruz              157
# 123           Feb Afan Antolin              140
# 141  0i1ck3bbu7s2w6r0m7mz8xl4x              114
# 107        Joan Aringo Aycardo              106
#
# [200 rows x 6 columns]

# %%
playlist_df.to_csv("playlist_data.csv",encoding='utf=8',index=False)

# %% [markdown]
# ## View structure of a playlist_tracks query

# %%
track = sp.playlist_tracks('37i9dQZF1DX4olOMiqFeqU')

# %%
track
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4olOMiqFeqU/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7374lH6kwx9uQATYQ9H3Cp'},
#        'href': 'https://api.spotify.com/v1/artists/7374lH6kwx9uQATYQ9H3Cp',
#        'id': '7374lH6kwx9uQATYQ9H3Cp',
#        'name': 'Eraserheads',
#        'type': 'artist',
#        'uri': 'spotify:artist:7374lH6kwx9uQATYQ9H3Cp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2DIpgoeZAbwk3wF1qSDj8v'},
#      'href': 'https://api.spotify.com/v1/albums/2DIpgoeZAbwk3wF1qSDj8v',
#      'id': '2DIpgoeZAbwk3wF1qSDj8v',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27383a474e86be1eebb17df6726',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0283a474e86be1eebb17df6726',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485183a474e86be1eebb17df6726',
#        'width': 64}],
#      'name': 'Anthology',
#      'release_date': '2004-01-23',
#      'release_date_precision': 'day',
#      'total_tracks': 33,
#      'type': 'album',
#      'uri': 'spotify:album:2DIpgoeZAbwk3wF1qSDj8v'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7374lH6kwx9uQATYQ9H3Cp'},
#       'href': 'https://api.spotify.com/v1/artists/7374lH6kwx9uQATYQ9H3Cp',
#       'id': '7374lH6kwx9uQATYQ9H3Cp',
#       'name': 'Eraserheads',
#       'type': 'artist',
#       'uri': 'spotify:artist:7374lH6kwx9uQATYQ9H3Cp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 271466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHBO10100222'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6SHSvo6OGgpneKfsxFGhhk'},
#     'href': 'https://api.spotify.com/v1/tracks/6SHSvo6OGgpneKfsxFGhhk',
#     'id': '6SHSvo6OGgpneKfsxFGhhk',
#     'is_local': False,
#     'name': 'Ligaya',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fca7a630556bff734e9f56a3efd8e0c3a1c6c2cb?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6SHSvo6OGgpneKfsxFGhhk'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#        'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#        'id': '6aiCKnIN68hohzU3ZzNq48',
#        'name': 'Sarah Geronimo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/42F8uTX1DR3OiaKVtrz3Gr'},
#      'href': 'https://api.spotify.com/v1/albums/42F8uTX1DR3OiaKVtrz3Gr',
#      'id': '42F8uTX1DR3OiaKVtrz3Gr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a8ce1962ab70fd8b7d062c2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a8ce1962ab70fd8b7d062c2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a8ce1962ab70fd8b7d062c2',
#        'width': 64}],
#      'name': 'The Great Unknown',
#      'release_date': '2015-12-04',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:42F8uTX1DR3OiaKVtrz3Gr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#       'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#       'id': '6aiCKnIN68hohzU3ZzNq48',
#       'name': 'Sarah Geronimo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 245053,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHV031510085'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4T7CM071eEoHudiDShZlCJ'},
#     'href': 'https://api.spotify.com/v1/tracks/4T7CM071eEoHudiDShZlCJ',
#     'id': '4T7CM071eEoHudiDShZlCJ',
#     'is_local': False,
#     'name': 'Tala',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9e7b3a5bf3240651896e045107338ea6a3bd66f6?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:4T7CM071eEoHudiDShZlCJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HIZU0JzM0AgfItVOm4E08'},
#        'href': 'https://api.spotify.com/v1/artists/5HIZU0JzM0AgfItVOm4E08',
#        'id': '5HIZU0JzM0AgfItVOm4E08',
#        'name': 'This Band',
#        'type': 'artist',
#        'uri': 'spotify:artist:5HIZU0JzM0AgfItVOm4E08'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2sGiNJNhNMJbn56l0BE0R0'},
#      'href': 'https://api.spotify.com/v1/albums/2sGiNJNhNMJbn56l0BE0R0',
#      'id': '2sGiNJNhNMJbn56l0BE0R0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273229f723cc430e9d2d8a5920a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02229f723cc430e9d2d8a5920a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851229f723cc430e9d2d8a5920a',
#        'width': 64}],
#      'name': 'Kahit Ayaw Mo Na',
#      'release_date': '2018-11-02',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2sGiNJNhNMJbn56l0BE0R0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HIZU0JzM0AgfItVOm4E08'},
#       'href': 'https://api.spotify.com/v1/artists/5HIZU0JzM0AgfItVOm4E08',
#       'id': '5HIZU0JzM0AgfItVOm4E08',
#       'name': 'This Band',
#       'type': 'artist',
#       'uri': 'spotify:artist:5HIZU0JzM0AgfItVOm4E08'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 243015,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCGH1864517'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/58grXgbCj7t5ulr0TGLIr9'},
#     'href': 'https://api.spotify.com/v1/tracks/58grXgbCj7t5ulr0TGLIr9',
#     'id': '58grXgbCj7t5ulr0TGLIr9',
#     'is_local': False,
#     'name': 'Kahit Ayaw Mo Na',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1dbe606aa34cd8fa75caedd742dc2310728226f7?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:58grXgbCj7t5ulr0TGLIr9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4qFxP3qN9GsnZDOkAE6x2m'},
#        'href': 'https://api.spotify.com/v1/artists/4qFxP3qN9GsnZDOkAE6x2m',
#        'id': '4qFxP3qN9GsnZDOkAE6x2m',
#        'name': 'December Avenue',
#        'type': 'artist',
#        'uri': 'spotify:artist:4qFxP3qN9GsnZDOkAE6x2m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7xconhHQKj7Be4P2KvUmFz'},
#      'href': 'https://api.spotify.com/v1/albums/7xconhHQKj7Be4P2KvUmFz',
#      'id': '7xconhHQKj7Be4P2KvUmFz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273266d80116545e01826910bbd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02266d80116545e01826910bbd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851266d80116545e01826910bbd',
#        'width': 64}],
#      'name': 'Sa Ngalan Ng Pag-Ibig',
#      'release_date': '2017-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7xconhHQKj7Be4P2KvUmFz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4qFxP3qN9GsnZDOkAE6x2m'},
#       'href': 'https://api.spotify.com/v1/artists/4qFxP3qN9GsnZDOkAE6x2m',
#       'id': '4qFxP3qN9GsnZDOkAE6x2m',
#       'name': 'December Avenue',
#       'type': 'artist',
#       'uri': 'spotify:artist:4qFxP3qN9GsnZDOkAE6x2m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 285138,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMPKX1753025'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/00mBzIWv5gHOYxwuEJXjOG'},
#     'href': 'https://api.spotify.com/v1/tracks/00mBzIWv5gHOYxwuEJXjOG',
#     'id': '00mBzIWv5gHOYxwuEJXjOG',
#     'is_local': False,
#     'name': 'Sa Ngalan Ng Pag-Ibig',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4626adec259ce7f45bf99b287a1f263fa38e5dd1?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:00mBzIWv5gHOYxwuEJXjOG'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BNWanhw4AjSXjBm9L1Jzy'},
#        'href': 'https://api.spotify.com/v1/artists/4BNWanhw4AjSXjBm9L1Jzy',
#        'id': '4BNWanhw4AjSXjBm9L1Jzy',
#        'name': 'Juris',
#        'type': 'artist',
#        'uri': 'spotify:artist:4BNWanhw4AjSXjBm9L1Jzy'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7nEylzolYuExnVXy0TCPie'},
#      'href': 'https://api.spotify.com/v1/albums/7nEylzolYuExnVXy0TCPie',
#      'id': '7nEylzolYuExnVXy0TCPie',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734b1aa56e662e44b9dbd1ddcb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024b1aa56e662e44b9dbd1ddcb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514b1aa56e662e44b9dbd1ddcb',
#        'width': 64}],
#      'name': 'Forevermore',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7nEylzolYuExnVXy0TCPie'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BNWanhw4AjSXjBm9L1Jzy'},
#       'href': 'https://api.spotify.com/v1/artists/4BNWanhw4AjSXjBm9L1Jzy',
#       'id': '4BNWanhw4AjSXjBm9L1Jzy',
#       'name': 'Juris',
#       'type': 'artist',
#       'uri': 'spotify:artist:4BNWanhw4AjSXjBm9L1Jzy'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 294716,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS091104168'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3U7TJUjNz7pgPSfgeGQjsP'},
#     'href': 'https://api.spotify.com/v1/tracks/3U7TJUjNz7pgPSfgeGQjsP',
#     'id': '3U7TJUjNz7pgPSfgeGQjsP',
#     'is_local': False,
#     'name': 'Forevermore',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/43999982ee26ace4a48a993568ed062b04145746?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3U7TJUjNz7pgPSfgeGQjsP'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#        'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#        'id': '0rZRTXEmmPmx6gt92tBqIc',
#        'name': 'Moira Dela Torre',
#        'type': 'artist',
#        'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/52xu8EP3ABmpNk0LUzF3ih'},
#      'href': 'https://api.spotify.com/v1/albums/52xu8EP3ABmpNk0LUzF3ih',
#      'id': '52xu8EP3ABmpNk0LUzF3ih',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b6a618ab41335201afc16b81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b6a618ab41335201afc16b81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b6a618ab41335201afc16b81',
#        'width': 64}],
#      'name': 'Malaya (Camp Sawi Original Motion Picture Soundtrack)',
#      'release_date': '2017-09-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:52xu8EP3ABmpNk0LUzF3ih'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#       'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#       'id': '0rZRTXEmmPmx6gt92tBqIc',
#       'name': 'Moira Dela Torre',
#       'type': 'artist',
#       'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 254249,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB-SMU-29-78835'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6M21eWbEw74XDdoQsNIinq'},
#     'href': 'https://api.spotify.com/v1/tracks/6M21eWbEw74XDdoQsNIinq',
#     'id': '6M21eWbEw74XDdoQsNIinq',
#     'is_local': False,
#     'name': 'Malaya (Camp Sawi Original Motion Picture Soundtrack)',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/278202994437dd2ec90fbed0c08b5317eff4ad21?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6M21eWbEw74XDdoQsNIinq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nGp682WMiKS4X217kPw8C'},
#        'href': 'https://api.spotify.com/v1/artists/4nGp682WMiKS4X217kPw8C',
#        'id': '4nGp682WMiKS4X217kPw8C',
#        'name': 'Silent Sanctuary',
#        'type': 'artist',
#        'uri': 'spotify:artist:4nGp682WMiKS4X217kPw8C'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/38jqi8VvSax4miNL2cacD1'},
#      'href': 'https://api.spotify.com/v1/albums/38jqi8VvSax4miNL2cacD1',
#      'id': '38jqi8VvSax4miNL2cacD1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27324e40ba8327d578c9413ce36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0224e40ba8327d578c9413ce36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485124e40ba8327d578c9413ce36',
#        'width': 64}],
#      'name': 'Langit. Luha.',
#      'release_date': '2015-04-08',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:38jqi8VvSax4miNL2cacD1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nGp682WMiKS4X217kPw8C'},
#       'href': 'https://api.spotify.com/v1/artists/4nGp682WMiKS4X217kPw8C',
#       'id': '4nGp682WMiKS4X217kPw8C',
#       'name': 'Silent Sanctuary',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nGp682WMiKS4X217kPw8C'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 241029,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHI011405630'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0YyM8aEdbjGfLWPn6fdcn7'},
#     'href': 'https://api.spotify.com/v1/tracks/0YyM8aEdbjGfLWPn6fdcn7',
#     'id': '0YyM8aEdbjGfLWPn6fdcn7',
#     'is_local': False,
#     'name': 'Pasensya Ka Na',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/671a52310fa06ef356df56c51b6826560ce90765?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0YyM8aEdbjGfLWPn6fdcn7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Is0yeBka3hK5PSob7HTLs'},
#      'href': 'https://api.spotify.com/v1/albums/2Is0yeBka3hK5PSob7HTLs',
#      'id': '2Is0yeBka3hK5PSob7HTLs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d56bb7a4d884f0f02cac382b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d56bb7a4d884f0f02cac382b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d56bb7a4d884f0f02cac382b',
#        'width': 64}],
#      'name': 'Vince & Kath & James (Original Motion Picture Soundtrack)',
#      'release_date': '2016-12-16',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:2Is0yeBka3hK5PSob7HTLs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qnQOnL1oLKtH779qZ6iuR'},
#       'href': 'https://api.spotify.com/v1/artists/2qnQOnL1oLKtH779qZ6iuR',
#       'id': '2qnQOnL1oLKtH779qZ6iuR',
#       'name': 'Ylona Garcia',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qnQOnL1oLKtH779qZ6iuR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/69ug07KFFRhcCZ7iZ1Mn1i'},
#       'href': 'https://api.spotify.com/v1/artists/69ug07KFFRhcCZ7iZ1Mn1i',
#       'id': '69ug07KFFRhcCZ7iZ1Mn1i',
#       'name': 'Bailey May',
#       'type': 'artist',
#       'uri': 'spotify:artist:69ug07KFFRhcCZ7iZ1Mn1i'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 217453,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS091605475'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6bLMHyeVCs2ki3nPUEhAjR'},
#     'href': 'https://api.spotify.com/v1/tracks/6bLMHyeVCs2ki3nPUEhAjR',
#     'id': '6bLMHyeVCs2ki3nPUEhAjR',
#     'is_local': False,
#     'name': 'O Pag-Ibig',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a832f1e678489f5aae527776481d40e5962ef39c?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6bLMHyeVCs2ki3nPUEhAjR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#        'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#        'id': '6aiCKnIN68hohzU3ZzNq48',
#        'name': 'Sarah Geronimo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BGReR0ClYIme8zAabt53h'},
#      'href': 'https://api.spotify.com/v1/albums/0BGReR0ClYIme8zAabt53h',
#      'id': '0BGReR0ClYIme8zAabt53h',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27354977fc898459edc2b4a325c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0254977fc898459edc2b4a325c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485154977fc898459edc2b4a325c',
#        'width': 64}],
#      'name': 'Maybe This Time (From "Maybe This Time")',
#      'release_date': '2016-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0BGReR0ClYIme8zAabt53h'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#       'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#       'id': '6aiCKnIN68hohzU3ZzNq48',
#       'name': 'Sarah Geronimo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 255608,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS031400391'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Dljpp52vCmtXi0E94qjfo'},
#     'href': 'https://api.spotify.com/v1/tracks/0Dljpp52vCmtXi0E94qjfo',
#     'id': '0Dljpp52vCmtXi0E94qjfo',
#     'is_local': False,
#     'name': 'Maybe This Time - From "Maybe This Time"',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/34dc88427eb27b665a6f77525553cf5f612164df?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0Dljpp52vCmtXi0E94qjfo'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0DnjaQqb436AH1idffI6CQ'},
#        'href': 'https://api.spotify.com/v1/artists/0DnjaQqb436AH1idffI6CQ',
#        'id': '0DnjaQqb436AH1idffI6CQ',
#        'name': 'Yeng Constantino',
#        'type': 'artist',
#        'uri': 'spotify:artist:0DnjaQqb436AH1idffI6CQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4oSnCQpi32oI4UdUw2rKRL'},
#      'href': 'https://api.spotify.com/v1/albums/4oSnCQpi32oI4UdUw2rKRL',
#      'id': '4oSnCQpi32oI4UdUw2rKRL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d13ffbc4234b8f71e5394150',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d13ffbc4234b8f71e5394150',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d13ffbc4234b8f71e5394150',
#        'width': 64}],
#      'name': 'Metamorphosis',
#      'release_date': '2013-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4oSnCQpi32oI4UdUw2rKRL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0DnjaQqb436AH1idffI6CQ'},
#       'href': 'https://api.spotify.com/v1/artists/0DnjaQqb436AH1idffI6CQ',
#       'id': '0DnjaQqb436AH1idffI6CQ',
#       'name': 'Yeng Constantino',
#       'type': 'artist',
#       'uri': 'spotify:artist:0DnjaQqb436AH1idffI6CQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 226876,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS091304595'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/57NF2cTqsTx11rOlNKkwWA'},
#     'href': 'https://api.spotify.com/v1/tracks/57NF2cTqsTx11rOlNKkwWA',
#     'id': '57NF2cTqsTx11rOlNKkwWA',
#     'is_local': False,
#     'name': 'Chinito',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/205905857e68101fa4e8a9dd3c7cd34b118e9a57?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:57NF2cTqsTx11rOlNKkwWA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62WbvkXqQGvXQvw74GU3kQ'},
#        'href': 'https://api.spotify.com/v1/artists/62WbvkXqQGvXQvw74GU3kQ',
#        'id': '62WbvkXqQGvXQvw74GU3kQ',
#        'name': 'Morissette',
#        'type': 'artist',
#        'uri': 'spotify:artist:62WbvkXqQGvXQvw74GU3kQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
# ...
#     'href': 'https://api.spotify.com/v1/tracks/2S80c51YXgJQhkhX603fMA',
#     'id': '2S80c51YXgJQhkhX603fMA',
#     'is_local': False,
#     'name': 'Prinsesa',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/73dd68cc9e3a170dcba6457cbb470b16c7832f30?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2S80c51YXgJQhkhX603fMA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/33qqYIFSFSVYO3wCkc1Ksh'},
#      'href': 'https://api.spotify.com/v1/albums/33qqYIFSFSVYO3wCkc1Ksh',
#      'id': '33qqYIFSFSVYO3wCkc1Ksh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e79447782758701854a62cef',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e79447782758701854a62cef',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e79447782758701854a62cef',
#        'width': 64}],
#      'name': 'Pauwi Nako',
#      'release_date': '2018-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:33qqYIFSFSVYO3wCkc1Ksh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iqkVK6sTXi7DZWWOeKy8Q'},
#       'href': 'https://api.spotify.com/v1/artists/0iqkVK6sTXi7DZWWOeKy8Q',
#       'id': '0iqkVK6sTXi7DZWWOeKy8Q',
#       'name': 'PDL',
#       'type': 'artist',
#       'uri': 'spotify:artist:0iqkVK6sTXi7DZWWOeKy8Q'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/117XFtbZPnCI1EYKjYZWJc'},
#       'href': 'https://api.spotify.com/v1/artists/117XFtbZPnCI1EYKjYZWJc',
#       'id': '117XFtbZPnCI1EYKjYZWJc',
#       'name': 'Skusta Clee',
#       'type': 'artist',
#       'uri': 'spotify:artist:117XFtbZPnCI1EYKjYZWJc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0uD1WQbTE0pNDiJe0iGEaU'},
#       'href': 'https://api.spotify.com/v1/artists/0uD1WQbTE0pNDiJe0iGEaU',
#       'id': '0uD1WQbTE0pNDiJe0iGEaU',
#       'name': 'Jnske',
#       'type': 'artist',
#       'uri': 'spotify:artist:0uD1WQbTE0pNDiJe0iGEaU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5MfvrLwRcs98YwS3C9Uf1u'},
#       'href': 'https://api.spotify.com/v1/artists/5MfvrLwRcs98YwS3C9Uf1u',
#       'id': '5MfvrLwRcs98YwS3C9Uf1u',
#       'name': 'Bullet D',
#       'type': 'artist',
#       'uri': 'spotify:artist:5MfvrLwRcs98YwS3C9Uf1u'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xOvrnVpLjzfGi69GDlzQY'},
#       'href': 'https://api.spotify.com/v1/artists/5xOvrnVpLjzfGi69GDlzQY',
#       'id': '5xOvrnVpLjzfGi69GDlzQY',
#       'name': 'Yuridope',
#       'type': 'artist',
#       'uri': 'spotify:artist:5xOvrnVpLjzfGi69GDlzQY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3PDFGpPl4ienSn5Vwisfrh'},
#       'href': 'https://api.spotify.com/v1/artists/3PDFGpPl4ienSn5Vwisfrh',
#       'id': '3PDFGpPl4ienSn5Vwisfrh',
#       'name': 'Flow G',
#       'type': 'artist',
#       'uri': 'spotify:artist:3PDFGpPl4ienSn5Vwisfrh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 341573,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADT1835182'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2tzAN1L07SNwnOdgOEeuQr'},
#     'href': 'https://api.spotify.com/v1/tracks/2tzAN1L07SNwnOdgOEeuQr',
#     'id': '2tzAN1L07SNwnOdgOEeuQr',
#     'is_local': False,
#     'name': 'Pauwi Nako',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/26122cea968dfa29f6270901cbab215158b01a2b?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2tzAN1L07SNwnOdgOEeuQr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#        'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#        'id': '0rZRTXEmmPmx6gt92tBqIc',
#        'name': 'Moira Dela Torre',
#        'type': 'artist',
#        'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/05rQadwAVYTpNNnBoeTuj0'},
#      'href': 'https://api.spotify.com/v1/albums/05rQadwAVYTpNNnBoeTuj0',
#      'id': '05rQadwAVYTpNNnBoeTuj0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27384c39a72230ca78d8223dcec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0284c39a72230ca78d8223dcec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485184c39a72230ca78d8223dcec',
#        'width': 64}],
#      'name': 'Malaya',
#      'release_date': '2018-02-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:05rQadwAVYTpNNnBoeTuj0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#       'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#       'id': '0rZRTXEmmPmx6gt92tBqIc',
#       'name': 'Moira Dela Torre',
#       'type': 'artist',
#       'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 320320,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS031700772'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/70bc7AZ8MN5niphOXyHpsD'},
#     'href': 'https://api.spotify.com/v1/tracks/70bc7AZ8MN5niphOXyHpsD',
#     'id': '70bc7AZ8MN5niphOXyHpsD',
#     'is_local': False,
#     'name': 'Malaya',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fe7a31b266d4b9f2487b4e38cf133db05ef0480e?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:70bc7AZ8MN5niphOXyHpsD'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-06-15T10:31:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0DnjaQqb436AH1idffI6CQ'},
#        'href': 'https://api.spotify.com/v1/artists/0DnjaQqb436AH1idffI6CQ',
#        'id': '0DnjaQqb436AH1idffI6CQ',
#        'name': 'Yeng Constantino',
#        'type': 'artist',
#        'uri': 'spotify:artist:0DnjaQqb436AH1idffI6CQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6jojHOgC3f8MNsBBW9ta4D'},
#      'href': 'https://api.spotify.com/v1/albums/6jojHOgC3f8MNsBBW9ta4D',
#      'id': '6jojHOgC3f8MNsBBW9ta4D',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736e86ebbb6680fa23bf65b353',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026e86ebbb6680fa23bf65b353',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516e86ebbb6680fa23bf65b353',
#        'width': 64}],
#      'name': 'Yeng 10 (Remastered) [10 Years of Yeng Constantino]',
#      'release_date': '2016-10-03',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:6jojHOgC3f8MNsBBW9ta4D'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0DnjaQqb436AH1idffI6CQ'},
#       'href': 'https://api.spotify.com/v1/artists/0DnjaQqb436AH1idffI6CQ',
#       'id': '0DnjaQqb436AH1idffI6CQ',
#       'name': 'Yeng Constantino',
#       'type': 'artist',
#       'uri': 'spotify:artist:0DnjaQqb436AH1idffI6CQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 290506,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS090702322'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ASMzDRBfvLPwn7eXkknFB'},
#     'href': 'https://api.spotify.com/v1/tracks/5ASMzDRBfvLPwn7eXkknFB',
#     'id': '5ASMzDRBfvLPwn7eXkknFB',
#     'is_local': False,
#     'name': 'Salamat',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16dff3211e4b0a72e603e82f68b1743b3f751237?cid=fa095b525c424f17b54dc347ca561dcd',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5ASMzDRBfvLPwn7eXkknFB'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 50}

# %%
track.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
track['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %% [markdown]
# ## Get Tracks Data

# %%
def get_relevant_track_data(tracks_data, playlist_id):
    try:
        relevant_track_data = { key: tracks_data['track'][key] for key in ['id','artists','name','popularity','duration_ms'] }
        relevant_track_data['artist_id']=[artist['id'] for artist in relevant_track_data['artists'] ]
        relevant_track_data['artist_name']=[artist['name']for artist in relevant_track_data['artists'] ]
        relevant_track_data['num_artists']=len([artist['id'] for artist in relevant_track_data['artists']]) 
        relevant_track_data['playlist_id']=playlist_id
        relevant_track_data.pop('artists', None)
        return relevant_track_data
    except:
        return

# %%
#playlist_tracks
all_track_data = []

for p_name,p_id, p_numtracks in list(zip(playlist_names,playlist_ids,playlist_numtracks)):
    print("Fetching data for playlist %s with total tracks: %d" % (p_name,p_numtracks))
    n_fetches = p_numtracks // 100
    
    playlist_track_data = []
    
    for n in np.arange(n_fetches+1):
        track_data = sp.playlist_tracks(p_id, offset=n*100)
        playlist_track_data.extend([get_relevant_track_data(item, p_id) for item in track_data['items']])
        
    all_track_data.extend(playlist_track_data)
# Out:
# Fetching data for playlist OPM Favorites with total tracks: 50
# Fetching data for playlist OPM Says Chillax with total tracks: 40
# Fetching data for playlist OPM Bands 90's - 00's with total tracks: 348
# Fetching data for playlist OPM Chill Songs 2020 ☕ with total tracks: 49
# Fetching data for playlist OPM: Hits of the '00s with total tracks: 40
# Fetching data for playlist OPM: Hits of the '90s with total tracks: 35
# Fetching data for playlist OPM Lovesongs 80's 90's 20's with total tracks: 285
# Fetching data for playlist OPM: Hits of the '80s with total tracks: 40
# Fetching data for playlist OPM Classics with total tracks: 267
# Fetching data for playlist OPM Rising with total tracks: 80
# Fetching data for playlist OPM 2020 Playlist with total tracks: 40
# Fetching data for playlist OPM 2000s (Batang 90s) with total tracks: 148
# Fetching data for playlist  with total tracks: 47
# Fetching data for playlist OPM Bands Greatest Hits with total tracks: 66
# Fetching data for playlist OPM HUGOT SONG 2020 with total tracks: 45
# Fetching data for playlist OPM Acoustic Hits 2020 💛 with total tracks: 77
# Fetching data for playlist OPM Workday Marathon with total tracks: 140
# Fetching data for playlist OPM Hits 2019 -2020 with total tracks: 35
# Fetching data for playlist OPM Love songs 80s and 90s Ballads with total tracks: 83
# Fetching data for playlist OPM Love Songs & Covers with total tracks: 91
# Fetching data for playlist OPM TAGALOG LOVE SONGS 80's and 90's with total tracks: 87
# Fetching data for playlist OPM Sad Songs☹️ with total tracks: 94
# Fetching data for playlist OPM Songs 2020 - OPM Love Songs Tagalog Playlist 2020 (New Filipino Song) with total tracks: 40
# Fetching data for playlist OPM Rock & Alternative 90's - 2010's with total tracks: 209
# Fetching data for playlist OPM Songs for Sleeping 😴 with total tracks: 268
# Fetching data for playlist OPM Inuman Sessions with total tracks: 334
# Fetching data for playlist OPM Alternative Rock Hits with total tracks: 145
# Fetching data for playlist OPM 70's 80's Tagalog with total tracks: 496
# Fetching data for playlist Acoustically OPM with total tracks: 40
# Fetching data for playlist OPM Rock Songs with total tracks: 109
# Fetching data for playlist Top Hits Philippines with total tracks: 52
# Fetching data for playlist Acoustic OPM with total tracks: 130
# Fetching data for playlist Tatak Pinoy with total tracks: 60
# Fetching data for playlist Men of OPM with total tracks: 60
# Fetching data for playlist OPM Hits 2020 to 2021 with total tracks: 194
# Fetching data for playlist Top OPM Artists of 2018 with total tracks: 30
# Fetching data for playlist Women of OPM with total tracks: 70
# Fetching data for playlist Christmas OPM with total tracks: 14
# Fetching data for playlist Top OPM Artists of 2019 with total tracks: 30
# Fetching data for playlist Broken Hearted OPM Songs 2020 💔 with total tracks: 48
# Fetching data for playlist Rap Songs OPM 2020 with total tracks: 43
# Fetching data for playlist Filipino Songs (OPM) with total tracks: 298
# Fetching data for playlist Chill OPM Songs with total tracks: 105
# Fetching data for playlist Chocolate Factory & OPM reggae with total tracks: 27
# Fetching data for playlist Pinoy Band Opm hits with total tracks: 118
# Fetching data for playlist Pinoy Classic Rock with total tracks: 61
# Fetching data for playlist Tunog Kalye / Pinoy Rock OPM Bands 90's with total tracks: 167
# Fetching data for playlist Best of Manila Sound with total tracks: 40
# Fetching data for playlist TAGALOG SONGS (OPM) with total tracks: 36
# Fetching data for playlist TUNOG KALYE (90"S OPM BANDS) with total tracks: 96
# Fetching data for playlist 90's OPM bands with total tracks: 27
# Fetching data for playlist Love Songs OPM 00's with total tracks: 90
# Fetching data for playlist 90s OPM Pinoy Love Songs with total tracks: 88
# Fetching data for playlist 2000s OPM Nostalgia with total tracks: 170
# Fetching data for playlist This Is Eraserheads with total tracks: 27
# Fetching data for playlist Bago Sa Rap with total tracks: 60
# Fetching data for playlist Pampatulog / Acoustic OPM with total tracks: 56
# Fetching data for playlist Pinoy Reggae with total tracks: 31
# Fetching data for playlist TRENDING OPM 2020  with total tracks: 14
# Fetching data for playlist Pinoy Covers with total tracks: 65
# Fetching data for playlist OPM Rap Music with total tracks: 116
# Fetching data for playlist Freestyle — OPM Medley and Side A with total tracks: 22
# Fetching data for playlist Jukebox OPM Hits with total tracks: 120
# Fetching data for playlist Wish 107.5 OPM with total tracks: 125
# Fetching data for playlist Broken hearted OPM Tagalog with total tracks: 176
# Fetching data for playlist Pinoy Rakrakan! with total tracks: 50
# Fetching data for playlist OPM Band Hits with total tracks: 174
# Fetching data for playlist Pinoy Love Ballads with total tracks: 60
# Fetching data for playlist Regae OPM with total tracks: 31
# Fetching data for playlist Tagalog' OPM Hits..... with total tracks: 39
# Fetching data for playlist BATANG 90's OPM Greatest Hits with total tracks: 86
# Fetching data for playlist Trending OPM Hits 2020 with total tracks: 65
# Fetching data for playlist OPM MASHUP 2020 💕 with total tracks: 32
# Fetching data for playlist New OPM Love Songs 2020 - Tagalog Music Playlist with total tracks: 40
# Fetching data for playlist Roadtrip Hits OPM Philippines with total tracks: 43
# Fetching data for playlist Disney Hits Philippines with total tracks: 50
# Fetching data for playlist O kay sarap sa ilalim ng kalawakan Kapag kapiling kang tumitig sa kawalan Saksi ang buwan at bituin with total tracks: 44
# Fetching data for playlist Filipino Love Songs ❣️ 🇵🇭  | OPM with total tracks: 108
# Fetching data for playlist Pinoy Rap 2020 👑 with total tracks: 85
# Fetching data for playlist Best OPM Hits 2020 - OPM Love Songs Tagalog Playlist with total tracks: 40
# Fetching data for playlist Break-Up Playlist (OPM) with total tracks: 87
# Fetching data for playlist Bass Boosted OPM with total tracks: 83
# Fetching data for playlist Jaya OPM with total tracks: 19
# Fetching data for playlist Tagalog Opm lovesongs with total tracks: 62
# Fetching data for playlist Old School OPM Hits with total tracks: 161
# Fetching data for playlist OPM Acoustic Covers ❤️ with total tracks: 34
# Fetching data for playlist Morning OPM with total tracks: 49
# Fetching data for playlist Saxophone 🎷 OPM with total tracks: 17
# Fetching data for playlist Pinoy acoustics and Senti OPM with total tracks: 71
# Fetching data for playlist Mood: Sad OPM with total tracks: 172
# Fetching data for playlist OPM: Pasko Na Naman with total tracks: 24
# Fetching data for playlist New Music Friday Philippines with total tracks: 106
# Fetching data for playlist BEST OF OPM RAP SONGS  with total tracks: 99
# Fetching data for playlist OPM LOVE SONGS with total tracks: 93
# Fetching data for playlist Rainy Night's OPM Jam with total tracks: 35
# Fetching data for playlist Heart Breaking Songs💔OPM🖤 with total tracks: 66
# Fetching data for playlist Classic OPM Bands with total tracks: 138
# Fetching data for playlist OPM love song 2020 with total tracks: 43
# Fetching data for playlist Indie OPM Feels with total tracks: 59
# Fetching data for playlist OPM Birit Songs with total tracks: 41
# Fetching data for playlist Latest OPM Songs with total tracks: 28
# Fetching data for playlist OPM/Tagalog Christmas Songs with total tracks: 167
# Fetching data for playlist OPM Old Tagalog Love songs 💕 with total tracks: 48
# Fetching data for playlist Sad Songs Philippines 2020 😢 with total tracks: 34
# Fetching data for playlist Pinoy Love Songs 2020 ❤ with total tracks: 80
# Fetching data for playlist 2000's OPM Band Hits with total tracks: 118
# Fetching data for playlist OPM acoustic love songs with total tracks: 56
# Fetching data for playlist Mashup opm 2020 with total tracks: 29
# Fetching data for playlist Trending Hits Philippines 2020 with total tracks: 66
# Fetching data for playlist Old Opm songs tagalog with total tracks: 144
# Fetching data for playlist Bagong OPM 2020 with total tracks: 13
# Fetching data for playlist Religious Songs-OPM with total tracks: 51
# Fetching data for playlist OPM Bands 2004-2010 with total tracks: 212
# Fetching data for playlist Tagalog OPM Best 90's/2000's hits with total tracks: 99
# Fetching data for playlist Senti - OPM with total tracks: 175
# Fetching data for playlist SENTI OPM HITS with total tracks: 225
# Fetching data for playlist Locals (OPM) 🇵🇭 with total tracks: 217
# Fetching data for playlist Filipino OPM songs with total tracks: 202
# Fetching data for playlist Opm 2020 lovesong with total tracks: 77
# Fetching data for playlist Wish107.5 OPM mix  with total tracks: 106
# Fetching data for playlist Nina, MYMP, Freestyle & OPM's with total tracks: 169
# Fetching data for playlist Mellow OPM with total tracks: 102
# Fetching data for playlist This Is Sponge Cola with total tracks: 37
# Fetching data for playlist Opm acoustic covers with total tracks: 51
# Fetching data for playlist OPM Jukebox Hits📀📀📀 with total tracks: 76
# Fetching data for playlist alternative rock #opm🇵🇭🇵🇭 with total tracks: 141
# Fetching data for playlist NEW OPM Pinoy Covers 🌺 2019-2020 with total tracks: 69
# Fetching data for playlist OPM Tiktok Hits 2020! 💃 with total tracks: 40
# Fetching data for playlist Heartbreak Songs OPM 🇵🇭 with total tracks: 347
# Fetching data for playlist OPM Top Hits 2020 with total tracks: 108
# Fetching data for playlist Philippine OPM/Senti 2020 with total tracks: 31
# Fetching data for playlist OPM 2000s & Late 90s with total tracks: 263
# Fetching data for playlist Classic OPM Rock with total tracks: 89
# Fetching data for playlist Tunog Kalye (OPM 90's Bands) with total tracks: 66
# Fetching data for playlist 1990s (OPM) with total tracks: 64
# Fetching data for playlist NEW OPM 2019-2020 with total tracks: 184
# Fetching data for playlist NEW OPM RAP 2020 with total tracks: 237
# Fetching data for playlist Opm rock 2000's with total tracks: 316
# Fetching data for playlist OPM English Songs with total tracks: 173
# Fetching data for playlist OPM 90s - Chill with total tracks: 58
# Fetching data for playlist OPM English Love Songs 2020 💓 with total tracks: 90
# Fetching data for playlist OPM Christmas songs with total tracks: 62
# Fetching data for playlist OPM 🇵🇭 mood with total tracks: 45
# Fetching data for playlist april boy songs and opm  with total tracks: 55
# Fetching data for playlist OPM sa Tag-Ulan 2020☔ with total tracks: 61
# Fetching data for playlist Sunday OPM classics with total tracks: 104
# Fetching data for playlist 2000's opm love songs with total tracks: 53
# Fetching data for playlist OPM CLASSIC (‘70s & ‘80s hits) with total tracks: 88
# Fetching data for playlist opm 80's to 90's with total tracks: 97
# Fetching data for playlist Reggae Pilipinas with total tracks: 35
# Fetching data for playlist Reggae Pilipinas with total tracks: 35
# Fetching data for playlist Cinderella OPM with total tracks: 49
# Fetching data for playlist OPM Sad Songs 2020 😢 with total tracks: 60
# Fetching data for playlist OPM Hits 90's & 2000's with total tracks: 211
# Fetching data for playlist 80's OPM Love Songs with total tracks: 40
# Fetching data for playlist OPM HIPHOP 2020 with total tracks: 18
# Fetching data for playlist Pinoy OPM with total tracks: 71
# Fetching data for playlist Pinoy Alt Rock with total tracks: 80
# Fetching data for playlist OPM CHRISTMAS with total tracks: 112
# Fetching data for playlist Best OPM Band Collection with total tracks: 190
# Fetching data for playlist 2005-2006 OPM Songs with total tracks: 86
# Fetching data for playlist OPM Piano Covers with total tracks: 54
# Fetching data for playlist RNB OPM LOVE SONGS with total tracks: 101
# Fetching data for playlist Classic OPM love songs with total tracks: 140
# Fetching data for playlist OPM Fever  with total tracks: 30
# Fetching data for playlist Top Opm 2020 with total tracks: 178
# Fetching data for playlist Hugot Songs / OPM with total tracks: 98
# Fetching data for playlist OPM Chill with total tracks: 131
# Fetching data for playlist OPM Band Hits 2020 🎸 with total tracks: 49
# Fetching data for playlist OPM Acoustic/Mellow Rock with total tracks: 179
# Fetching data for playlist Best OPM of all time with total tracks: 53
# Fetching data for playlist Tagalog opm bands 2020 with total tracks: 42
# Fetching data for playlist OPM TAGALOG HITS 80'90 with total tracks: 116
# Fetching data for playlist OPM Pampatulog Love Songs with total tracks: 32
# Fetching data for playlist OPM Instrumental Hits with total tracks: 63
# Fetching data for playlist OPM 80s-90's Jukebox with total tracks: 51
# Fetching data for playlist opm ktv with total tracks: 87
# Fetching data for playlist Tagalog Rap/OPM 2020! with total tracks: 37
# Fetching data for playlist OPM Alternative 90s with total tracks: 78
# Fetching data for playlist OPM alternative/rock 90s - 2020 with total tracks: 332
# Fetching data for playlist 90's opm love songs ❤ with total tracks: 19
# Fetching data for playlist OPM Acoustic/Soul/Love Songs with total tracks: 258
# Fetching data for playlist Pinoy Rnb 2020 💜 with total tracks: 51
# Fetching data for playlist Classic OPM Rap and OPM Hip-Hop with total tracks: 39
# Fetching data for playlist OPM Sunday Jukebox with total tracks: 123
# Fetching data for playlist OPM Oldies - Jukebox Hits with total tracks: 44
# Fetching data for playlist OPM 2004 to 2007 with total tracks: 55
# Fetching data for playlist Female BIRIT songs (intl & opm) with total tracks: 109
# Fetching data for playlist Lasing na broken - OPM with total tracks: 95
# Fetching data for playlist Pabagalin muna natin ang ikot ng mundo Pahintuin mga kamay ng oras sa relo with total tracks: 67
# Fetching data for playlist Filipino Love Songs OPM with total tracks: 28
# Fetching data for playlist OPM | Higa, Tulala, Iyak with total tracks: 56
# Fetching data for playlist Tagalog Senti Songs 2020 💔 with total tracks: 47
# Fetching data for playlist OPM love radio 90.7 with total tracks: 89
# Fetching data for playlist 80's OPM ballads with total tracks: 280
# Fetching data for playlist Year 2000 OPM Bands with total tracks: 211
# Fetching data for playlist OPM alternative rocks with total tracks: 137
# Fetching data for playlist COVER,OPM & SENTI SONGS with total tracks: 92
# Fetching data for playlist OPM Tagalog Songs with total tracks: 189
# Fetching data for playlist OPM Best Pinoy Pampatulog Songs with total tracks: 197

# %%
len(all_track_data[0])
# Out:
# 8

# %%
len(all_track_data)
# Out:
# 19547

# %%
for n,a in enumerate(all_track_data):
    try:
        len(a)
    except:
        print(n)
# Out:
# 1675
# 7199

# %%
tracks_df = pd.DataFrame([data for data in all_track_data if data is not None])
tracks_df = tracks_df.rename(columns={'id':'track_id'})
tracks_df['artist_id'] = tracks_df.apply(lambda x: x['artist_id'][0] if x['num_artists']==1 else x['artist_id'], axis=1)
tracks_df['artist_name'] = tracks_df.apply(lambda x: x['artist_name'][0] if x['num_artists']==1 else x['artist_name'], axis=1)
tracks_df.head()
# Out:
#                  track_id                   name  popularity  duration_ms  \
# 0  6SHSvo6OGgpneKfsxFGhhk                 Ligaya          56       271466
# 1  4T7CM071eEoHudiDShZlCJ                   Tala          64       245053
# 2  58grXgbCj7t5ulr0TGLIr9       Kahit Ayaw Mo Na          66       243015
# 3  00mBzIWv5gHOYxwuEJXjOG  Sa Ngalan Ng Pag-Ibig          67       285138
# 4  3U7TJUjNz7pgPSfgeGQjsP            Forevermore          59       294716
#
#                 artist_id      artist_name  num_artists  \
# 0  7374lH6kwx9uQATYQ9H3Cp      Eraserheads            1
# 1  6aiCKnIN68hohzU3ZzNq48   Sarah Geronimo            1
# 2  5HIZU0JzM0AgfItVOm4E08        This Band            1
# 3  4qFxP3qN9GsnZDOkAE6x2m  December Avenue            1
# 4  4BNWanhw4AjSXjBm9L1Jzy            Juris            1
#
#               playlist_id
# 0  37i9dQZF1DX4olOMiqFeqU
# 1  37i9dQZF1DX4olOMiqFeqU
# 2  37i9dQZF1DX4olOMiqFeqU
# 3  37i9dQZF1DX4olOMiqFeqU
# 4  37i9dQZF1DX4olOMiqFeqU

# %%
tracks_df.to_csv("playlist_tracks.csv",encoding='utf=8',index=False)

# %%
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])
